# %%
import sys
import os
import numpy as np

custom_path = os.path.join(
    os.getcwd(), "/scr/matthewh6/robot_pref"
)  # or a relative/absolute path
if custom_path not in sys.path:
    sys.path.append(custom_path)

# %%
from utils.env import get_robomimic_env, wrap_env
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv


def make_env_fn(seed):
    def _init():
        env = get_robomimic_env(
            "/scr/shared/datasets/robot_pref/stack_mixed/stack_mixed.hdf5", seed=seed
        )
        return env

    return _init


env = DummyVecEnv([make_env_fn(seed) for seed in range(2)])
# env_fns = [make_env_fn(seed) for seed in range(2)]
# env = SubprocVecEnv(env_fns)
# Out:
# Created environment with name Stack_D0
# Action size is 7
# /scr/matthewh6/miniconda3/envs/pref/lib/python3.9/site-packages/gymnasium/spaces/box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /scr/matthewh6/miniconda3/envs/pref/lib/python3.9/site-packages/gymnasium/spaces/box.py:305: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Created environment with name Stack_D0
# Action size is 7

# %%
env.action_space.shape[0]
# Out:
# 7

# %%
action_dim = env.action_space.shape[0]
actions = np.array([env.action_space.sample() for _ in range(env.num_envs)])
actions = actions.astype(np.float32)

# %%
states = env.reset()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 states, info = env.reset()
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
states["state"].shape
# Out:
# (2, 32)

# %%
env.render().shape
# Out:
# (448, 224, 3)

# %%
env.render_mode = "rgb_array"

[setattr(env, "render_mode", "rgb_array") for env in env.envs]
# Out:
# array([[[115, 113, 110],
#         [114, 112, 108],
#         [115, 112, 109],
#         ...,
#         [116, 114, 110],
#         [116, 114, 111],
#         [116, 114, 110]],
#
#        [[116, 114, 111],
#         [115, 112, 109],
#         [115, 112, 109],
#         ...,
#         [116, 114, 111],
#         [116, 115, 111],
#         [116, 114, 110]],
#
#        [[116, 114, 111],
#         [115, 113, 110],
#         [115, 113, 109],
#         ...,
#         [117, 115, 111],
#         [116, 114, 110],
#         [115, 113, 110]],
#
#        ...,
#
#        [[248, 247, 242],
#         [247, 246, 241],
#         [247, 245, 241],
#         ...,
#         [251, 251, 247],
#         [251, 251, 246],
#         [251, 251, 246]],
#
#        [[247, 246, 242],
#         [246, 247, 242],
#         [247, 247, 242],
#         ...,
#         [250, 250, 245],
#         [250, 250, 246],
#         [252, 251, 247]],
#
#        [[247, 247, 241],
#         [248, 248, 244],
#         [247, 247, 241],
#         ...,
#         [251, 252, 246],
#         [251, 252, 247],
#         [252, 251, 246]]], dtype=uint8)

# %%
env.envs[1].render()
# Out:
# array([[[115, 113, 110],
#         [114, 112, 108],
#         [115, 112, 109],
#         ...,
#         [116, 114, 110],
#         [116, 114, 111],
#         [116, 114, 110]],
#
#        [[116, 114, 111],
#         [115, 112, 109],
#         [115, 112, 109],
#         ...,
#         [116, 114, 111],
#         [116, 115, 111],
#         [116, 114, 110]],
#
#        [[116, 114, 111],
#         [115, 113, 110],
#         [115, 113, 109],
#         ...,
#         [117, 115, 111],
#         [116, 114, 110],
#         [115, 113, 110]],
#
#        ...,
#
#        [[248, 247, 242],
#         [247, 246, 241],
#         [247, 245, 241],
#         ...,
#         [251, 251, 247],
#         [251, 251, 246],
#         [251, 251, 246]],
#
#        [[247, 246, 242],
#         [246, 247, 242],
#         [247, 247, 242],
#         ...,
#         [250, 250, 245],
#         [250, 250, 246],
#         [252, 251, 247]],
#
#        [[247, 247, 241],
#         [248, 248, 244],
#         [247, 247, 241],
#         ...,
#         [251, 252, 246],
#         [251, 252, 247],
#         [252, 251, 246]]], dtype=uint8)
